# %%
from simulator.simulations.specific.PanamaDrill import PanamaDrill
drill = PanamaDrill()
drill.simulate()
# Out:
# /Users/andreaparra/Virtual-Envs/python_3.9/lib/python3.9/site-packages/geopandas/_compat.py:124: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.9.1-CAPI-1.14.2). Conversions between both will be slow.
#   warnings.warn(
#    Reading nodes from Cache
#    Reading edges from Cache
# 2017-08-20 00:00:00
#    Population in area of interest: 5628
#    Generating Disaster
#       Number of steps to compute: 87759 hr
#    Disaster has not started
# 2017-08-20 04:00:00
#    Population in area of interest: 3678
#    Disaster has not started
# 2017-08-20 08:00:00
#    Population in area of interest: 2480
#    Disaster has not started
# 2017-08-20 12:00:00
#    Population in area of interest: 2940
#    Disaster has not started
# 2017-08-20 16:00:00
#    Population in area of interest: 2374
#    Disaster has not started
# 2017-08-20 20:00:00
#    Population in area of interest: 2641
#    Disaster has not started
# ...
